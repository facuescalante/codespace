# %% [markdown]
# # Clase 12
#
# ## Pandas DataFrame
#
# los dataframe son tablas parecidas a una hoja de calculo, contienen filas y columnas. cada una de estas filas individualmente es una Serie

# %% [markdown]
# ## Ejercicio 1.0

# %%
# !pip install pandas==2.2.2
# Out:
# Requirement already satisfied: pandas==2.2.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==2.2.2) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.16.0)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Ejercicio 1.1
#
# creacion objeto DataFrame

# %%
# creamos un dataframe extrayendo los datos de las listas
lista_p1 = ["Juan Pablo", "Simone", 54, False]
lista_p2 = ["Yul","Mourad",46,True]
lista_p3 = ["Carlos","Alverca",75,False]
lista_p4 = ["Jorge","Rodriguez",38,False]
lista_p5 = ["Sebastian","First",48,False]
lista_p6 = ["Mabel","Guzman",26,False]
lista_p7 = ["Yanina","Delgado",29,False]
lista_p8 = ["Marina","Mery",49,False]

lista_nombre_columnas = ["Nombre","Apellido","Edad","Es metido?"]

df_alumnos = pd.DataFrame(
    data = [lista_p1,lista_p2,lista_p3,lista_p4,lista_p5,lista_p6,lista_p7,lista_p8],
    columns = lista_nombre_columnas
)
df_alumnos
# Out:
#        Nombre   Apellido  Edad  Es metido?
# 0  Juan Pablo     Simone    54       False
# 1         Yul     Mourad    46        True
# 2      Carlos    Alverca    75       False
# 3       Jorge  Rodriguez    38       False
# 4   Sebastian      First    48       False
# 5       Mabel     Guzman    26       False
# 6      Yanina    Delgado    29       False
# 7      Marina       Mery    49       False

# %%
# podemos crear un dataFrame extrayendo los datos de un diccionario

diccionario_empleados = {
    "Nombre" : ["Mara","Mirta","Jose","Juana"],
    "Departamento" : ["Sales","IT","IT","JR"],
    "Suledo_usd" : [1200,5000,7600,8000],
    "Facturacion" : [True,True,False,True]
}
diccionario_empleados
# Out:
# {'Nombre': ['Mara', 'Mirta', 'Jose', 'Juana'],
#  'Departamento': ['Sales', 'IT', 'IT', 'JR'],
#  'Suledo_usd': [1200, 5000, 7600, 8000],
#  'Facturacion': [True, True, False, True]}

# %%
df_empleados = pd.DataFrame(diccionario_empleados)

df_empleados
# Out:
#   Nombre Departamento  Suledo_usd  Facturacion
# 0   Mara        Sales        1200         True
# 1  Mirta           IT        5000         True
# 2   Jose           IT        7600        False
# 3  Juana           JR        8000         True

# %%
rng = np.random.default_rng()

# %%
array_5x3 = rng.integers(1,20,(5,3)) #creacion array
print(array_5x3)
# Out:
# [[14  2  6]
#  [ 4 17 14]
#  [ 8  7 12]
#  [ 6 19  6]
#  [ 7  6 10]]

# %%
array_5x3.ndim
# Out:
# 2

# %%
array_5x3.shape
# Out:
# (5, 3)

# %%
#tambien podemos crear un dataframe a partir de un array

# %% [markdown]
# ## Ejercicio 1.2
#
# podemos trabajar con indices personalizados

# %%
# Estamos integrando el indice a partir de una lista

# dataframe catalogo vehiculos disponibles en una concecionaria

lista_patente = ["GHY-548","ERG-105","TPE-485","POL-896"]

lista_v1 = ["Ford","Mustang",100000,True]
lista_v2 = ["Fiat","500",50000,False]
lista_v3 = ["Toyota","Yaris",75000,True]
lista_v4 = ["Toyota","Corolla",150000,True]

lista_encabezado_concecionaria = ["Marca", "Modelo", "Precio", "0Km"]

df_vehiculos = pd.DataFrame(
    data = [lista_v1,lista_v2,lista_v3,lista_v4],
    columns = lista_encabezado_concecionaria,
    index = lista_patente
)
df_vehiculos
# Out:
#           Marca   Modelo  Precio    0Km
# GHY-548    Ford  Mustang  100000   True
# ERG-105    Fiat      500   50000  False
# TPE-485  Toyota    Yaris   75000   True
# POL-896  Toyota  Corolla  150000   True

# %%
# Podemos seleccionar el indice desde una columna de mi dataframe

#Tengo un diccionario con empleados
diccionario_empleados = {
  "ID":["F-001","C-001","F-002","F-003","F-004","C-002"],
  "Nombre":["Andres","Sofia","Mercedes","Pablo","Claudia","Miguel"],
  "Apellido":["Muñoz","Cerves","Garcia","Alaves","Perez","Solis"],
  "Sueldo":[4500,6000,2300,5300,4920,5000],
  "Departamento":["IT","Sales","IT","IT","HR","Sales"],
  "Facturacion":[True,True,False,True,True,False]
}

df_empleado2 = pd.DataFrame(diccionario_empleados)
df_empleado2
# Out:
#       ID    Nombre Apellido  Sueldo Departamento  Facturacion
# 0  F-001    Andres    Muñoz    4500           IT         True
# 1  C-001     Sofia   Cerves    6000        Sales         True
# 2  F-002  Mercedes   Garcia    2300           IT        False
# 3  F-003     Pablo   Alaves    5300           IT         True
# 4  F-004   Claudia    Perez    4920           HR         True
# 5  C-002    Miguel    Solis    5000        Sales        False

# %%
df_empleado2.set_index("ID", inplace=True)
df_empleado2
# Out:
#          Nombre Apellido  Sueldo Departamento  Facturacion
# ID
# F-001    Andres    Muñoz    4500           IT         True
# C-001     Sofia   Cerves    6000        Sales         True
# F-002  Mercedes   Garcia    2300           IT        False
# F-003     Pablo   Alaves    5300           IT         True
# F-004   Claudia    Perez    4920           HR         True
# C-002    Miguel    Solis    5000        Sales        False

# %%
# El indice pueden ser fechas

dias = pd.date_range(start='2024-01-10', end='2024-04-19')

df_resumen_ventas = pd.DataFrame(
    data = {
        "nro_ventas":rng.integers(10,50,len(dias)),
        "ganancia":rng.random(len(dias)).round(2),
        "ingresos_en_miles_usd":rng.integers(100,2000,len(dias))
    },
    index=dias)
df_resumen_ventas
# Out:
#             nro_ventas  ganancia  ingresos_en_miles_usd
# 2024-01-10          29      0.77                   1939
# 2024-01-11          18      0.46                   1719
# 2024-01-12          35      0.04                   1811
# 2024-01-13          41      0.41                    522
# 2024-01-14          38      0.51                    105
# ...                ...       ...                    ...
# 2024-04-15          34      0.60                   1488
# 2024-04-16          11      0.63                   1068
# 2024-04-17          35      0.52                   1775
# 2024-04-18          13      0.59                   1247
# 2024-04-19          29      0.79                    841
#
# [101 rows x 3 columns]

# %% [markdown]
# ## Ejercicio 1.3
#
# Repaso metodos importantes que sirven para trabajar con dataframes

# %%
df_resumen_ventas.head(7)  #Head nos trae los primeros N elementos
# Out:
#             nro_ventas  ganancia  ingresos_en_miles_usd
# 2024-01-10          29      0.77                   1939
# 2024-01-11          18      0.46                   1719
# 2024-01-12          35      0.04                   1811
# 2024-01-13          41      0.41                    522
# 2024-01-14          38      0.51                    105
# 2024-01-15          26      0.57                   1095
# 2024-01-16          11      0.72                   1315

# %%
df_resumen_ventas.tail()  #Tail trae los ultimos N elementos, el valor por defecto es 5
# Out:
#             nro_ventas  ganancia  ingresos_en_miles_usd
# 2024-04-15          34      0.60                   1488
# 2024-04-16          11      0.63                   1068
# 2024-04-17          35      0.52                   1775
# 2024-04-18          13      0.59                   1247
# 2024-04-19          29      0.79                    841

# %%
df_resumen_ventas.describe() #Uso describe
# Out:
#        nro_ventas    ganancia  ingresos_en_miles_usd
# count  101.000000  101.000000             101.000000
# mean    27.990099    0.488416            1115.544554
# std     10.978611    0.289992             554.712728
# min     10.000000    0.010000             104.000000
# 25%     18.000000    0.250000             705.000000
# 50%     27.000000    0.480000            1126.000000
# 75%     37.000000    0.790000            1628.000000
# max     49.000000    0.990000            1993.000000

# %%
df_resumen_ventas.shape #Tenemos 101 filas por 3 columnas
# Out:
# (101, 3)

# %%
df_resumen_ventas.nro_ventas #Aisla la columna -> Serie
# Out:
# 2024-01-10    29
# 2024-01-11    18
# 2024-01-12    35
# 2024-01-13    41
# 2024-01-14    38
#               ..
# 2024-04-15    34
# 2024-04-16    11
# 2024-04-17    35
# 2024-04-18    13
# 2024-04-19    29
# Freq: D, Name: nro_ventas, Length: 101, dtype: int64

# %%
df_resumen_ventas[df_resumen_ventas.ingresos_en_miles_usd > 1400] #Puedo filtrar mi dataframe aplicandole una regla a una columna (Series)
# Out:
#             nro_ventas  ganancia  ingresos_en_miles_usd
# 2024-01-10          29      0.77                   1939
# 2024-01-11          18      0.46                   1719
# 2024-01-12          35      0.04                   1811
# 2024-01-19          35      0.25                   1774
# 2024-01-22          19      0.57                   1727
# 2024-01-25          14      0.22                   1636
# 2024-01-27          17      0.39                   1456
# 2024-02-03          48      0.36                   1960
# 2024-02-07          18      0.14                   1419
# 2024-02-09          42      0.65                   1587
# 2024-02-10          36      0.56                   1646
# 2024-02-12          27      0.92                   1550
# 2024-02-13          39      0.01                   1738
# 2024-02-17          34      0.28                   1628
# 2024-02-21          18      0.85                   1688
# 2024-02-28          40      0.45                   1749
# 2024-03-04          27      0.32                   1803
# 2024-03-06          37      0.36                   1884
# 2024-03-09          38      0.99                   1877
# 2024-03-11          38      0.09                   1671
# 2024-03-19          28      0.97                   1949
# 2024-03-21          46      0.84                   1723
# 2024-03-22          15      0.09                   1718
# 2024-03-24          42      0.01                   1993
# 2024-03-25          19      0.80                   1890
# 2024-03-27          24      0.20                   1886
# 2024-03-28          41      0.81                   1760
# 2024-04-01          15      0.55                   1949
# 2024-04-03          44      0.07                   1927
# 2024-04-06          14      0.05                   1583
# 2024-04-12          36      0.16                   1480
# 2024-04-15          34      0.60                   1488
# 2024-04-17          35      0.52                   1775

# %%
 #Podemos concatenar diferentes reglas

df_resumen_ventas[(df_resumen_ventas.nro_ventas > 40) & (df_resumen_ventas.ingresos_en_miles_usd > 1600)]
# Out:
#             nro_ventas  ganancia  ingresos_en_miles_usd
# 2024-02-03          48      0.36                   1960
# 2024-03-21          46      0.84                   1723
# 2024-03-24          42      0.01                   1993
# 2024-03-28          41      0.81                   1760
# 2024-04-03          44      0.07                   1927

# %%
df_resumen_ventas.iloc[0] #Obtenemos el primer elemento
# Out:
# nro_ventas                 29.00
# ganancia                    0.77
# ingresos_en_miles_usd    1939.00
# Name: 2024-01-10 00:00:00, dtype: float64

# %%
df_resumen_ventas.iloc[3] #Obtenemos el cuarto elemento
# Out:
# nro_ventas                41.00
# ganancia                   0.41
# ingresos_en_miles_usd    522.00
# Name: 2024-01-13 00:00:00, dtype: float64

# %%
df_resumen_ventas.iloc[-1] #Ultimo elemento
# Out:
# nro_ventas                29.00
# ganancia                   0.79
# ingresos_en_miles_usd    841.00
# Name: 2024-04-19 00:00:00, dtype: float64

# %%
df_resumen_ventas.iloc[4:10] #Filtrado desde la posicion 4 (incluida) hasta la 10(excluida)
# Out:
#             nro_ventas  ganancia  ingresos_en_miles_usd
# 2024-01-14          38      0.51                    105
# 2024-01-15          26      0.57                   1095
# 2024-01-16          11      0.72                   1315
# 2024-01-17          23      0.80                    325
# 2024-01-18          15      0.93                   1199
# 2024-01-19          35      0.25                   1774

# %%
df_resumen_ventas.iloc[:9] #El filtrado termina en 9 elemento
# Out:
#             nro_ventas  ganancia  ingresos_en_miles_usd
# 2024-01-10          29      0.77                   1939
# 2024-01-11          18      0.46                   1719
# 2024-01-12          35      0.04                   1811
# 2024-01-13          41      0.41                    522
# 2024-01-14          38      0.51                    105
# 2024-01-15          26      0.57                   1095
# 2024-01-16          11      0.72                   1315
# 2024-01-17          23      0.80                    325
# 2024-01-18          15      0.93                   1199

# %%
df_resumen_ventas.iloc[-15:] #El filtrado inicia desde el -15 adelante
# Out:
#             nro_ventas  ganancia  ingresos_en_miles_usd
# 2024-04-05          47      0.64                   1396
# 2024-04-06          14      0.05                   1583
# 2024-04-07          39      0.45                   1224
# 2024-04-08          28      0.09                    693
# 2024-04-09          25      0.14                    167
# 2024-04-10          10      0.01                   1285
# 2024-04-11          17      0.87                   1187
# 2024-04-12          36      0.16                   1480
# 2024-04-13          13      0.94                    220
# 2024-04-14          12      0.35                    104
# 2024-04-15          34      0.60                   1488
# 2024-04-16          11      0.63                   1068
# 2024-04-17          35      0.52                   1775
# 2024-04-18          13      0.59                   1247
# 2024-04-19          29      0.79                    841

# %%
df_resumen_ventas.sort_values(by="ganancia") #Ordenamos de menor a mayor nuestro dataframe en funcion de la ganancia
# Out:
#             nro_ventas  ganancia  ingresos_en_miles_usd
# 2024-03-24          42      0.01                   1993
# 2024-03-20          19      0.01                    589
# 2024-02-13          39      0.01                   1738
# 2024-04-10          10      0.01                   1285
# 2024-03-01          29      0.02                   1141
# ...                ...       ...                    ...
# 2024-01-18          15      0.93                   1199
# 2024-04-13          13      0.94                    220
# 2024-02-22          25      0.95                    331
# 2024-03-19          28      0.97                   1949
# 2024-03-09          38      0.99                   1877
#
# [101 rows x 3 columns]

# %%
#Ordenamos de mayor a menor nuestro dataframe en funcion de ingresos_mil_usd

df_resumen_ventas.sort_values(by="ingresos_en_miles_usd",ascending= False)
# Out:
#             nro_ventas  ganancia  ingresos_en_miles_usd
# 2024-03-24          42      0.01                   1993
# 2024-02-03          48      0.36                   1960
# 2024-04-01          15      0.55                   1949
# 2024-03-19          28      0.97                   1949
# 2024-01-10          29      0.77                   1939
# ...                ...       ...                    ...
# 2024-02-23          21      0.77                    128
# 2024-02-29          34      0.80                    122
# 2024-02-14          32      0.26                    106
# 2024-01-14          38      0.51                    105
# 2024-04-14          12      0.35                    104
#
# [101 rows x 3 columns]

# %% [markdown]
# ## Ejercicio 1.4
#
# Los dataframes son editables podemos cambiar aspectos como:
# * Renombrar columnas e indices en dataframe

# %%
dict_concesionaria = {
    'marca': ['Ford','Toyota','Audi','Ford','Ford','Renault','Chevrolet','Ford','Ford','Volkswagen','Honda','BMW','Mercedes-Benz','Ford','Ford'],
    'modelo': ['Focus','Hilux','A3','Mustang','F-100','Cactus','Spark','Escape','Explorer','Gol','Civic','X5','Clase C','Ranger','Fusion'],
    'precio': [3000,10000,10000,20000,2000,3500,4000,18000,25000,6000,8000,15000,12000,22000,17000],
    '0Km': [True,True,True,True,False,True,False,True,False,True,True,True,False,True,False]
  }
dict_concesionaria
# Out:
# {'marca': ['Ford',
#   'Toyota',
#   'Audi',
#   'Ford',
#   'Ford',
#   'Renault',
#   'Chevrolet',
#   'Ford',
#   'Ford',
#   'Volkswagen',
#   'Honda',
#   'BMW',
#   'Mercedes-Benz',
#   'Ford',
#   'Ford'],
#  'modelo': ['Focus',
#   'Hilux',
#   'A3',
#   'Mustang',
#   'F-100',
#   'Cactus',
#   'Spark',
#   'Escape',
#   'Explorer',
#   'Gol',
#   'Civic',
#   'X5',
#   'Clase C',
#   'Ranger',
#   'Fusion'],
#  'precio': [3000,
#   10000,
#   10000,
#   20000,
#   2000,
#   3500,
#   4000,
#   18000,
#   25000,
#   6000,
#   8000,
#   15000,
#   12000,
#   22000,
#   17000],
#  '0Km': [True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False]}

# %%
df_conce = pd.DataFrame(dict_concesionaria)
df_conce
# Out:
#             marca    modelo  precio    0Km
# 0            Ford     Focus    3000   True
# 1          Toyota     Hilux   10000   True
# 2            Audi        A3   10000   True
# 3            Ford   Mustang   20000   True
# 4            Ford     F-100    2000  False
# 5         Renault    Cactus    3500   True
# 6       Chevrolet     Spark    4000  False
# 7            Ford    Escape   18000   True
# 8            Ford  Explorer   25000  False
# 9      Volkswagen       Gol    6000   True
# 10          Honda     Civic    8000   True
# 11            BMW        X5   15000   True
# 12  Mercedes-Benz   Clase C   12000  False
# 13           Ford    Ranger   22000   True
# 14           Ford    Fusion   17000  False

# %%
#Podemos aplicar multiples condiciones que incluyan strings, booleanos e integers

df_conce[(df_conce.marca == "Ford") & (df_conce["precio"] > 10000) & (df_conce["0Km"] == True)]

 #Podemos aplicar la busqueda usando los corchetes y pasando el nombre de la columna
# Out:
#    marca   modelo  precio   0Km
# 3   Ford  Mustang   20000  True
# 7   Ford   Escape   18000  True
# 13  Ford   Ranger   22000  True

# %% [markdown]
# ### Podemos cambiar todos los nombres de las columnas

# %%
df_conce.head()
# Out:
#     marca   modelo  precio    0Km
# 0    Ford    Focus    3000   True
# 1  Toyota    Hilux   10000   True
# 2    Audi       A3   10000   True
# 3    Ford  Mustang   20000   True
# 4    Ford    F-100    2000  False

# %%
#Si queremos renombrar una columna debemos aplicar

nuevas_columns = {
    "marca":"MARCA",
    "modelo":"NOMBRE",
    "precio":"PRECIO_USD",
    "0Km":"UNICO_DUENO"
}

df_conce.rename(columns=nuevas_columns, inplace= True)

# %%
df_conce
# Out:
#             MARCA    NOMBRE  PRECIO_USD  UNICO_DUENO
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False

# %%
#Si queremos renombrar una columna debemos aplicar

df_conce.rename(columns={"MARCA":"MODELO"}, inplace=True)

df_conce
# Out:
#            MODELO    NOMBRE  PRECIO_USD  UNICO_DUENO
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False

# %%
#Podemos aplicar/renombrar nuestro indice generado por defecto

df_conce.index.rename(name="ID", inplace=True)

df_conce
# Out:
#            MODELO    NOMBRE  PRECIO_USD  UNICO_DUENO
# ID
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False

# %%
df_resumen_ventas.head()
# Out:
#             nro_ventas  ganancia  ingresos_en_miles_usd
# 2024-01-10          29      0.77                   1939
# 2024-01-11          18      0.46                   1719
# 2024-01-12          35      0.04                   1811
# 2024-01-13          41      0.41                    522
# 2024-01-14          38      0.51                    105

# %%
df_resumen_ventas.index.rename(name="dia", inplace=True)
df_resumen_ventas.rename(columns={"ganancia":"ganancia_%"}, inplace=True)
df_resumen_ventas
# Out:
#             nro_ventas  ganancia_%  ingresos_en_miles_usd
# dia
# 2024-01-10          29        0.77                   1939
# 2024-01-11          18        0.46                   1719
# 2024-01-12          35        0.04                   1811
# 2024-01-13          41        0.41                    522
# 2024-01-14          38        0.51                    105
# ...                ...         ...                    ...
# 2024-04-15          34        0.60                   1488
# 2024-04-16          11        0.63                   1068
# 2024-04-17          35        0.52                   1775
# 2024-04-18          13        0.59                   1247
# 2024-04-19          29        0.79                    841
#
# [101 rows x 3 columns]

# %% [markdown]
# ## Ejercicio 1.5
#
# como agregar o concatenar elementos a un dataframe

# %%
df_conce.rename(columns={"MODELO":"MARCA","NOMBRE":"MODELO"}, inplace=True)
df_conce  #Tenemos nuestro dataframe
# Out:
#             MARCA    MODELO  PRECIO_USD  UNICO_DUENO
# ID
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False

# %%
df_conce.shape #tenemos 15 filas y 4 columnas
# Out:
# (15, 4)

# %%
#Añado una nueva fila

new_vehiculo = pd.DataFrame(data=[
    ["Fiat","500",1200,False]
    ],
    columns=["MARCA","MODELO","PRECIO_USD","UNICO_DUENO"]
)
pd.concat([df_conce, new_vehiculo])
# Out:
#             MARCA    MODELO  PRECIO_USD  UNICO_DUENO
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False
# 0            Fiat       500        1200        False

# %%
#Puedo "sobreescribir" para tener todos los vehiculos en este dataframe

df_conce = pd.concat([df_conce, new_vehiculo], ignore_index=True) #Ignoramos el indice para que nuevo_vehiculo tenga un indice que continue con los numeros previos

df_conce
# Out:
#             MARCA    MODELO  PRECIO_USD  UNICO_DUENO
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False
# 15           Fiat       500        1200        False

# %%
df_conce.shape
# Out:
# (16, 4)

# %%
#Podemos agregar varios filas a la vez

vehiculos_import = pd.DataFrame(data={
    'MARCA': ['Bugatti','Ferrari','Audi'],
    'MODELO': ['Chiron','Enzo','R8'],
    'PRECIO_USD': [3210000,3200000,250000],
    'UNICO_DUENO': [True,True,True]
})
df_conce = pd.concat([df_conce, vehiculos_import], ignore_index=True)

df_conce
# Out:
#             MARCA    MODELO  PRECIO_USD  UNICO_DUENO
# 0            Ford     Focus        3000         True
# 1          Toyota     Hilux       10000         True
# 2            Audi        A3       10000         True
# 3            Ford   Mustang       20000         True
# 4            Ford     F-100        2000        False
# 5         Renault    Cactus        3500         True
# 6       Chevrolet     Spark        4000        False
# 7            Ford    Escape       18000         True
# 8            Ford  Explorer       25000        False
# 9      Volkswagen       Gol        6000         True
# 10          Honda     Civic        8000         True
# 11            BMW        X5       15000         True
# 12  Mercedes-Benz   Clase C       12000        False
# 13           Ford    Ranger       22000         True
# 14           Ford    Fusion       17000        False
# 15           Fiat       500        1200        False
# 16        Bugatti    Chiron     3210000         True
# 17        Ferrari      Enzo     3200000         True
# 18           Audi        R8      250000         True

# %%
df_conce.shape #Vemos como cambio la cantidad de filas y columnas
# Out:
# (19, 4)

# %%
#Tenemos que tener mucha precaucion ya que si no coinciden las columnas los valores se van a agregar generando nuevas columnas

vehiculos_import = pd.DataFrame(data={
    'fabricante': ['Bugatti','Ferrari','Audi'],
    'modelo': ['Chiron','Enzo','R8'],
    'costo': [3210000,3200000,250000],
    '0km': [True,True,True]
})
df_conce = pd.concat([df_conce, vehiculos_import], ignore_index=True)

df_conce
# Out:
#             MARCA    MODELO  PRECIO_USD UNICO_DUENO fabricante  modelo  \
# 0            Ford     Focus      3000.0        True        NaN     NaN
# 1          Toyota     Hilux     10000.0        True        NaN     NaN
# 2            Audi        A3     10000.0        True        NaN     NaN
# 3            Ford   Mustang     20000.0        True        NaN     NaN
# 4            Ford     F-100      2000.0       False        NaN     NaN
# 5         Renault    Cactus      3500.0        True        NaN     NaN
# 6       Chevrolet     Spark      4000.0       False        NaN     NaN
# 7            Ford    Escape     18000.0        True        NaN     NaN
# 8            Ford  Explorer     25000.0       False        NaN     NaN
# 9      Volkswagen       Gol      6000.0        True        NaN     NaN
# 10          Honda     Civic      8000.0        True        NaN     NaN
# 11            BMW        X5     15000.0        True        NaN     NaN
# 12  Mercedes-Benz   Clase C     12000.0       False        NaN     NaN
# 13           Ford    Ranger     22000.0        True        NaN     NaN
# 14           Ford    Fusion     17000.0       False        NaN     NaN
# 15           Fiat       500      1200.0       False        NaN     NaN
# 16        Bugatti    Chiron   3210000.0        True        NaN     NaN
# 17        Ferrari      Enzo   3200000.0        True        NaN     NaN
# 18           Audi        R8    250000.0        True        NaN     NaN
# 19            NaN       NaN         NaN         NaN    Bugatti  Chiron
# 20            NaN       NaN         NaN         NaN    Ferrari    Enzo
# 21            NaN       NaN         NaN         NaN       Audi      R8
#
#         costo   0km
# 0         NaN   NaN
# 1         NaN   NaN
# 2         NaN   NaN
# 3         NaN   NaN
# 4         NaN   NaN
# 5         NaN   NaN
# 6         NaN   NaN
# 7         NaN   NaN
# 8         NaN   NaN
# 9         NaN   NaN
# 10        NaN   NaN
# 11        NaN   NaN
# 12        NaN   NaN
# 13        NaN   NaN
# 14        NaN   NaN
# 15        NaN   NaN
# 16        NaN   NaN
# 17        NaN   NaN
# 18        NaN   NaN
# 19  3210000.0  True
# 20  3200000.0  True
# 21   250000.0  True

# %%
df_conce.shape #Vemos que ahora se duplicaron la cantidad de columnas
# Out:
# (22, 8)

# %% [markdown]
# ## Ejercicio 1.6
#
# Con los dataframe hay otra opcion muy usada y es el merge

# %%
df_empleados_cobro = pd.DataFrame({
    'ID': [101, 102, 103, 104],
    'Sueldo': [5000, 6000, 4500, 5500],
    'Facturacion': [True, True, False, True],
    'Antiguedad': [3, 5, 2, 8]
})

df_empleados_info = pd.DataFrame({
    'ID': [101, 102, 105, 106],
    'Edad': [31, 36, 29, 41],
    'Cargo': ['Analista', 'Gerente', 'Analista', 'Director'],
    'Nombre':["Pedro","Camila",'Mariano','Federico']
})

# %%
df_empleados_cobro
# Out:
#     ID  Sueldo  Facturacion  Antiguedad
# 0  101    5000         True           3
# 1  102    6000         True           5
# 2  103    4500        False           2
# 3  104    5500         True           8

# %%
df_empleados_info
# Out:
#     ID  Edad     Cargo    Nombre
# 0  101    31  Analista     Pedro
# 1  102    36   Gerente    Camila
# 2  105    29  Analista   Mariano
# 3  106    41  Director  Federico

# %%
#Left merge

df_let_merge = pd.merge(df_empleados_cobro,df_empleados_info,how="left",on='ID')
df_let_merge
# Out:
#     ID  Sueldo  Facturacion  Antiguedad  Edad     Cargo  Nombre
# 0  101    5000         True           3  31.0  Analista   Pedro
# 1  102    6000         True           5  36.0   Gerente  Camila
# 2  103    4500        False           2   NaN       NaN     NaN
# 3  104    5500         True           8   NaN       NaN     NaN

# %%
#Right merge (join sql)

df_right_merge = pd.merge(df_empleados_cobro,df_empleados_info,how="right",on='ID')

df_right_merge
# Out:
#     ID  Sueldo Facturacion  Antiguedad  Edad     Cargo    Nombre
# 0  101  5000.0        True         3.0    31  Analista     Pedro
# 1  102  6000.0        True         5.0    36   Gerente    Camila
# 2  105     NaN         NaN         NaN    29  Analista   Mariano
# 3  106     NaN         NaN         NaN    41  Director  Federico

# %%
df_empleados = pd.DataFrame({
    'ID': [101, 102, 103, 104],
    'Sueldo': [5000, 6000, 4500, 5500],
    'Edad': [30, 35, 28, 40],
    'Cargo': ['Analista', 'Gerente', 'Analista', 'Director'],
    'Facturacion': [True, True, False, True],
    'Antiguedad': [3, 5, 2, 8],
    'Departamento_ID':[1,2,4,3]
})
df_departamentos = pd.DataFrame({
    'Departamento_ID':[1,2,3],
    'Nombre':["Sales","IT","HR"],
    'Piso':[1,2,2],
    'Rotacion_24hs':[True,True,False]
})

# %%
df_empleados
# Out:
#     ID  Sueldo  Edad     Cargo  Facturacion  Antiguedad  Departamento_ID
# 0  101    5000    30  Analista         True           3                1
# 1  102    6000    35   Gerente         True           5                2
# 2  103    4500    28  Analista        False           2                4
# 3  104    5500    40  Director         True           8                3

# %%
df_departamentos
# Out:
#    Departamento_ID Nombre  Piso  Rotacion_24hs
# 0                1  Sales     1           True
# 1                2     IT     2           True
# 2                3     HR     2          False

# %%
#Inner merge

df_inner_merge = pd.merge(df_empleados,df_departamentos,how="inner",on="Departamento_ID")

df_inner_merge
# Out:
#     ID  Sueldo  Edad     Cargo  Facturacion  Antiguedad  Departamento_ID  \
# 0  101    5000    30  Analista         True           3                1
# 1  102    6000    35   Gerente         True           5                2
# 2  104    5500    40  Director         True           8                3
#
#   Nombre  Piso  Rotacion_24hs
# 0  Sales     1           True
# 1     IT     2           True
# 2     HR     2          False

# %%
#Outer merge

df_outer_merge = pd.merge(df_empleados,df_departamentos,how="outer",on="Departamento_ID")

df_outer_merge
# Out:
#     ID  Sueldo  Edad     Cargo  Facturacion  Antiguedad  Departamento_ID  \
# 0  101    5000    30  Analista         True           3                1
# 1  102    6000    35   Gerente         True           5                2
# 2  104    5500    40  Director         True           8                3
# 3  103    4500    28  Analista        False           2                4
#
#   Nombre  Piso Rotacion_24hs
# 0  Sales   1.0          True
# 1     IT   2.0          True
# 2     HR   2.0         False
# 3    NaN   NaN           NaN

# %% [markdown]
# ## Ejercicio 1.7
#
# En pandas podemos trabajar con los nulos, los cuales son valores faltantes o informacion perdida

# %%
semana = pd.date_range(start='2024-04-08', end='2024-04-14')

df_resumen_ventas = pd.DataFrame(
    data = {
        "clientes":[10,np.nan,12,16,20,np.nan,14],
        "pedidos":[4,2,14,10,1,10,12],
        "ingresos":[np.nan,20000,4500,7000,np.nan,5900,12000]
    },
    index=semana)
df_resumen_ventas
# Out:
#             clientes  pedidos  ingresos
# 2024-04-08      10.0        4       NaN
# 2024-04-09       NaN        2   20000.0
# 2024-04-10      12.0       14    4500.0
# 2024-04-11      16.0       10    7000.0
# 2024-04-12      20.0        1       NaN
# 2024-04-13       NaN       10    5900.0
# 2024-04-14      14.0       12   12000.0

# %%
#Vemos que valores son nulos
df_resumen_ventas.isnull ()
# Out:
#             clientes  pedidos  ingresos
# 2024-04-08     False    False      True
# 2024-04-09      True    False     False
# 2024-04-10     False    False     False
# 2024-04-11     False    False     False
# 2024-04-12     False    False      True
# 2024-04-13      True    False     False
# 2024-04-14     False    False     False

# %%
#Calculo de cuantas filas contienen nulos
df_resumen_ventas.isnull().sum()
# Out:
# clientes    2
# pedidos     0
# ingresos    2
# dtype: int64

# %%
#Deja solo las filas sin nulos
df_resumen_ventas.dropna()
# Out:
#             clientes  pedidos  ingresos
# 2024-04-10      12.0       14    4500.0
# 2024-04-11      16.0       10    7000.0
# 2024-04-14      14.0       12   12000.0

# %%
#Deja solo las columnas sin nulos
df_resumen_ventas.dropna(axis=1)
# Out:
#             pedidos
# 2024-04-08        4
# 2024-04-09        2
# 2024-04-10       14
# 2024-04-11       10
# 2024-04-12        1
# 2024-04-13       10
# 2024-04-14       12

# %%
# Rellenar los valores nulos con 0
df_resumen_ventas.fillna(0)
# Out:
#             clientes  pedidos  ingresos
# 2024-04-08      10.0        4       0.0
# 2024-04-09       0.0        2   20000.0
# 2024-04-10      12.0       14    4500.0
# 2024-04-11      16.0       10    7000.0
# 2024-04-12      20.0        1       0.0
# 2024-04-13       0.0       10    5900.0
# 2024-04-14      14.0       12   12000.0

# %%
df_resumen_ventas.median()
# Out:
# clientes      14.0
# pedidos       10.0
# ingresos    7000.0
# dtype: float64

# %%
#Reemplaza la media con la media de cada columna
df_resumen_ventas.fillna(df_resumen_ventas.median())
# Out:
#             clientes  pedidos  ingresos
# 2024-04-08      10.0        4    7000.0
# 2024-04-09      14.0        2   20000.0
# 2024-04-10      12.0       14    4500.0
# 2024-04-11      16.0       10    7000.0
# 2024-04-12      20.0        1    7000.0
# 2024-04-13      14.0       10    5900.0
# 2024-04-14      14.0       12   12000.0

# %%
#Se puede interpolar, aunque solo es recomendable cuando matematicamente la operacion tiene sentido
df_resumen_ventas.interpolate()
# Out:
#             clientes  pedidos  ingresos
# 2024-04-08      10.0        4       NaN
# 2024-04-09      11.0        2   20000.0
# 2024-04-10      12.0       14    4500.0
# 2024-04-11      16.0       10    7000.0
# 2024-04-12      20.0        1    6450.0
# 2024-04-13      17.0       10    5900.0
# 2024-04-14      14.0       12   12000.0
